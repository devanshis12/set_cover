# %%
#!/usr/bin/env python3
"""
This script runs the Branch and Bound algorithm on all input instance files (with extension .in)
in the "../data" directory and generates the corresponding solution (.sol) and trace (.trace)
output files in the "../output" directory.

The output file names follow the project specification:
    <instance>_BnB_<cutoff>.sol
    <instance>_BnB_<cutoff>.trace

Usage: from the command line, run "python run_all_bnb.py".
"""

import os
import time
from bnb import run_bnb  # Import the run_bnb function from bnb.py

def main():
    # Define the input and output directory paths relative to this script
    input_dir = os.path.join("..", "data")
    output_dir = os.path.join("..", "output")
    
    # Set the cutoff time (in seconds) for the BnB algorithm
    cutoff = 600  # 10 minutes
    
    # Get a sorted list of all input files ending with ".in" in the input directory
    in_files = sorted([f for f in os.listdir(input_dir) if f.endswith(".in")])
    
    if not in_files:
        print("No input files found in", input_dir)
        return

    print("Running Branch and Bound on the following input files:")
    print(in_files)
    print("-" * 40)
    
    for infile in in_files:
        file_path = os.path.join(input_dir, infile)
        instance_name = os.path.splitext(infile)[0]
        print(f"Running BnB on {infile} with cutoff {cutoff} seconds...")
        start_time = time.time()
        run_bnb(file_path, cutoff)
        elapsed = time.time() - start_time
        print(f"Completed {infile} in {elapsed:.2f} seconds.")
        
        # Construct expected output file names based on project format.
        sol_file = f"{instance_name}_BnB_{cutoff}.sol"
        trace_file = f"{instance_name}_BnB_{cutoff}.trace"
        sol_path = os.path.join(output_dir, sol_file)
        trace_path = os.path.join(output_dir, trace_file)
        
        # Report on the existence of solution and trace files.
        if os.path.exists(sol_path):
            print(f"Solution file generated: {sol_path}")
        else:
            print(f"Solution file not found: {sol_path}")
            
        if os.path.exists(trace_path):
            print(f"Trace file generated: {trace_path}")
        else:
            print(f"Trace file not found: {trace_path}")
        
        print("-" * 40)

if __name__ == "__main__":
    main()
# Out:
# Running Branch and Bound on the following input files:
# ['large1.in', 'large10.in', 'large11.in', 'large12.in', 'large2.in', 'large3.in', 'large4.in', 'large5.in', 'large6.in', 'large7.in', 'large8.in', 'large9.in', 'small1.in', 'small10.in', 'small11.in', 'small12.in', 'small13.in', 'small14.in', 'small15.in', 'small16.in', 'small17.in', 'small18.in', 'small2.in', 'small3.in', 'small4.in', 'small5.in', 'small6.in', 'small7.in', 'small8.in', 'small9.in', 'test1.in', 'test2.in', 'test3.in', 'test4.in', 'test5.in']
# ----------------------------------------
# Running BnB on large1.in with cutoff 600 seconds...
# Completed large1.in in 0.27 seconds.
# Solution file generated: ../output/large1_BnB_600.sol
# Trace file generated: ../output/large1_BnB_600.trace
# ----------------------------------------
# Running BnB on large10.in with cutoff 600 seconds...
# Completed large10.in in 600.01 seconds.
# Solution file generated: ../output/large10_BnB_600.sol
# Trace file generated: ../output/large10_BnB_600.trace
# ----------------------------------------
# Running BnB on large11.in with cutoff 600 seconds...
# Completed large11.in in 600.00 seconds.
# Solution file generated: ../output/large11_BnB_600.sol
# Trace file generated: ../output/large11_BnB_600.trace
# ----------------------------------------
# Running BnB on large12.in with cutoff 600 seconds...
# Completed large12.in in 600.00 seconds.
# Solution file generated: ../output/large12_BnB_600.sol
# Trace file generated: ../output/large12_BnB_600.trace
# ----------------------------------------
# Running BnB on large2.in with cutoff 600 seconds...
# Completed large2.in in 600.00 seconds.
# Solution file generated: ../output/large2_BnB_600.sol
# Trace file generated: ../output/large2_BnB_600.trace
# ----------------------------------------
# Running BnB on large3.in with cutoff 600 seconds...
# Completed large3.in in 600.00 seconds.
# Solution file generated: ../output/large3_BnB_600.sol
# Trace file generated: ../output/large3_BnB_600.trace
# ----------------------------------------
# Running BnB on large4.in with cutoff 600 seconds...
# Completed large4.in in 600.06 seconds.
# Solution file generated: ../output/large4_BnB_600.sol
# Trace file generated: ../output/large4_BnB_600.trace
# ----------------------------------------
# Running BnB on large5.in with cutoff 600 seconds...
# Completed large5.in in 600.00 seconds.
# Solution file generated: ../output/large5_BnB_600.sol
# Trace file generated: ../output/large5_BnB_600.trace
# ----------------------------------------
# Running BnB on large6.in with cutoff 600 seconds...
# Completed large6.in in 600.00 seconds.
# Solution file generated: ../output/large6_BnB_600.sol
# Trace file generated: ../output/large6_BnB_600.trace
# ----------------------------------------
# Running BnB on large7.in with cutoff 600 seconds...
# Completed large7.in in 600.01 seconds.
# Solution file generated: ../output/large7_BnB_600.sol
# Trace file generated: ../output/large7_BnB_600.trace
# ----------------------------------------
# Running BnB on large8.in with cutoff 600 seconds...
# Completed large8.in in 600.00 seconds.
# Solution file generated: ../output/large8_BnB_600.sol
# Trace file generated: ../output/large8_BnB_600.trace
# ----------------------------------------
# Running BnB on large9.in with cutoff 600 seconds...
# Completed large9.in in 600.00 seconds.
# Solution file generated: ../output/large9_BnB_600.sol
# Trace file generated: ../output/large9_BnB_600.trace
# ----------------------------------------
# Running BnB on small1.in with cutoff 600 seconds...
# Completed small1.in in 0.00 seconds.
# Solution file generated: ../output/small1_BnB_600.sol
# Trace file generated: ../output/small1_BnB_600.trace
# ----------------------------------------
# Running BnB on small10.in with cutoff 600 seconds...
# Completed small10.in in 0.00 seconds.
# Solution file generated: ../output/small10_BnB_600.sol
# Trace file generated: ../output/small10_BnB_600.trace
# ----------------------------------------
# Running BnB on small11.in with cutoff 600 seconds...
# Completed small11.in in 0.00 seconds.
# Solution file generated: ../output/small11_BnB_600.sol
# Trace file generated: ../output/small11_BnB_600.trace
# ----------------------------------------
# Running BnB on small12.in with cutoff 600 seconds...
# Completed small12.in in 0.00 seconds.
# Solution file generated: ../output/small12_BnB_600.sol
# Trace file generated: ../output/small12_BnB_600.trace
# ----------------------------------------
# Running BnB on small13.in with cutoff 600 seconds...
# Completed small13.in in 0.00 seconds.
# Solution file generated: ../output/small13_BnB_600.sol
# Trace file generated: ../output/small13_BnB_600.trace
# ----------------------------------------
# Running BnB on small14.in with cutoff 600 seconds...
# Completed small14.in in 0.00 seconds.
# Solution file generated: ../output/small14_BnB_600.sol
# Trace file generated: ../output/small14_BnB_600.trace
# ----------------------------------------
# Running BnB on small15.in with cutoff 600 seconds...
# Completed small15.in in 0.00 seconds.
# Solution file generated: ../output/small15_BnB_600.sol
# Trace file generated: ../output/small15_BnB_600.trace
# ----------------------------------------
# Running BnB on small16.in with cutoff 600 seconds...
# Completed small16.in in 0.00 seconds.
# Solution file generated: ../output/small16_BnB_600.sol
# Trace file generated: ../output/small16_BnB_600.trace
# ----------------------------------------
# Running BnB on small17.in with cutoff 600 seconds...
# Completed small17.in in 0.00 seconds.
# Solution file generated: ../output/small17_BnB_600.sol
# Trace file generated: ../output/small17_BnB_600.trace
# ----------------------------------------
# Running BnB on small18.in with cutoff 600 seconds...
# Completed small18.in in 0.00 seconds.
# Solution file generated: ../output/small18_BnB_600.sol
# Trace file generated: ../output/small18_BnB_600.trace
# ----------------------------------------
# Running BnB on small2.in with cutoff 600 seconds...
# Completed small2.in in 0.00 seconds.
# Solution file generated: ../output/small2_BnB_600.sol
# Trace file generated: ../output/small2_BnB_600.trace
# ----------------------------------------
# Running BnB on small3.in with cutoff 600 seconds...
# Completed small3.in in 0.00 seconds.
# Solution file generated: ../output/small3_BnB_600.sol
# Trace file generated: ../output/small3_BnB_600.trace
# ----------------------------------------
# Running BnB on small4.in with cutoff 600 seconds...
# Completed small4.in in 0.00 seconds.
# Solution file generated: ../output/small4_BnB_600.sol
# Trace file generated: ../output/small4_BnB_600.trace
# ----------------------------------------
# Running BnB on small5.in with cutoff 600 seconds...
# Completed small5.in in 0.00 seconds.
# Solution file generated: ../output/small5_BnB_600.sol
# Trace file generated: ../output/small5_BnB_600.trace
# ----------------------------------------
# Running BnB on small6.in with cutoff 600 seconds...
# Completed small6.in in 0.00 seconds.
# Solution file generated: ../output/small6_BnB_600.sol
# Trace file generated: ../output/small6_BnB_600.trace
# ----------------------------------------
# Running BnB on small7.in with cutoff 600 seconds...
# Completed small7.in in 0.00 seconds.
# Solution file generated: ../output/small7_BnB_600.sol
# Trace file generated: ../output/small7_BnB_600.trace
# ----------------------------------------
# Running BnB on small8.in with cutoff 600 seconds...
# Completed small8.in in 0.00 seconds.
# Solution file generated: ../output/small8_BnB_600.sol
# Trace file generated: ../output/small8_BnB_600.trace
# ----------------------------------------
# Running BnB on small9.in with cutoff 600 seconds...
# Completed small9.in in 0.00 seconds.
# Solution file generated: ../output/small9_BnB_600.sol
# Trace file generated: ../output/small9_BnB_600.trace
# ----------------------------------------
# Running BnB on test1.in with cutoff 600 seconds...
# Completed test1.in in 0.00 seconds.
# Solution file generated: ../output/test1_BnB_600.sol
# Trace file generated: ../output/test1_BnB_600.trace
# ----------------------------------------
# Running BnB on test2.in with cutoff 600 seconds...
# Completed test2.in in 0.00 seconds.
# Solution file generated: ../output/test2_BnB_600.sol
# Trace file generated: ../output/test2_BnB_600.trace
# ----------------------------------------
# Running BnB on test3.in with cutoff 600 seconds...
# Completed test3.in in 0.00 seconds.
# Solution file generated: ../output/test3_BnB_600.sol
# Trace file generated: ../output/test3_BnB_600.trace
# ----------------------------------------
# Running BnB on test4.in with cutoff 600 seconds...
# Completed test4.in in 0.00 seconds.
# Solution file generated: ../output/test4_BnB_600.sol
# Trace file generated: ../output/test4_BnB_600.trace
# ----------------------------------------
# Running BnB on test5.in with cutoff 600 seconds...
# Completed test5.in in 0.00 seconds.
# Solution file generated: ../output/test5_BnB_600.sol
# Trace file generated: ../output/test5_BnB_600.trace
# ----------------------------------------
